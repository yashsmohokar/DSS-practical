# %%
#Exp no:3
#aim:Basics of Data frame

# %%
# Name:Yash mohokar
# Roll no:38
# Sec:c
# Subject:ET-1
# Date:

# %%
import pandas as pd

# %%
Name=["Yash","Aadesh","Vedant","Shivam"]
Name
# Out:
# ['Yash', 'Aadesh', 'Vedant', 'Shivam']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4])
print(Roll_list)
# Out:
# 1      Yash
# 2    Aadesh
# 3    Vedant
# 4    Shivam
# dtype: object

# %% [markdown]
# Creating Data Frame

# %%
import pandas as pd

# %%
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
columns= ["BI","DBMS","DSS","CAO"])

# %%
df
# Out:
#    BI  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# Adding Record(row) to the data frame

# %%
import pandas as pd

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns= ["BI","DBMS","DSS","CAO"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    BI  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3   5     6    7    8

# %% [markdown]
# Adding Attribute (columns) name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    BI  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 1  11    18   15   21  15
# 2  12    13   14   15  16
# 3   5     6    7    8  14

# %% [markdown]
# Deleting Record From df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    BI  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 2  12    13   14   15  16
# 3   5     6    7    8  14

# %% [markdown]
# Deleting Attribute (columns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    BI  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3   5     6    7    8

# %%
print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 12.5

# %%
print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 14.0

# %%
print("Max of DSS:", df5["DSS"].max())
# Out:
# Max of DSS: 15
